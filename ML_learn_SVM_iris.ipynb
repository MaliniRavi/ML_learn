# %%
import pandas as pd
import numpy as np
from sklearn import svm, datasets
import matplotlib.pyplot as plt

iris_data = datasets.load_iris()
#iris_data

# %%
iris_data = datasets.load_iris()
X = iris_data.data[:, :2]
y = iris_data.target

#print (X,y)

plt.figure(figsize=(15, 5))
plt.subplot(121)
#plt.contourf(xx, yy, Z, cmap=plt.cm.tab10, alpha=0.3)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Set1)
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
#plt.xlim(xx.min(), xx.max())
plt.title('Support Vector Classifier without linear kernel')
# Out:
# Text(0.5, 1.0, 'Support Vector Classifier without linear kernel')

# %%
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
#print (x_min, x_max)
#print (X[:, 0])
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
h = (x_max / x_min)/100
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
X_plot = np.c_[xx.ravel(), yy.ravel()]

# %%
C=1.0

# %%
svc_classifier = svm.SVC(kernel='linear', C=C).fit(X, y)
Z = svc_classifier.predict(X_plot)
Z = Z.reshape(xx.shape)
print (Z.shape)
plt.figure(figsize=(15, 5))
plt.subplot(121)
plt.contourf(xx, yy, Z, cmap=plt.cm.tab10, alpha=0.3)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Set1)
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.xlim(xx.min(), xx.max())
plt.title('Support Vector Classifier with linear kernel')
# Out:
# (164, 208)
# Text(0.5, 1.0, 'Support Vector Classifier with linear kernel')

# %%
iris_data = datasets.load_iris()
X1 = iris_data.data[ :, 2:4]
y1 = iris_data.target

#print (X)

plt.figure(figsize=(15, 5))
plt.subplot(121)
#plt.contourf(xx, yy, Z, cmap=plt.cm.tab10, alpha=0.3)
plt.scatter(X1[:, 0], X1[:, 1], c=y1, cmap=plt.cm.Set1)
plt.xlabel('Petal length')
plt.ylabel('Petal width')
#plt.xlim(xx.min(), xx.max())
plt.title('Support Vector Classifier without linear kernel')
# Out:
# Text(0.5, 1.0, 'Support Vector Classifier without linear kernel')

# %%
x_min, x_max = X1[:, 0].min() - 1, X1[:, 0].max() + 1
print (x_min, x_max)
#print (X[:, 0])
y_min, y_max = X1[:, 1].min() - 1, X1[:, 1].max() + 1
h = (x_max / x_min)/100
xx1, yy1 = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
X_plot = np.c_[xx1.ravel(), yy1.ravel()]

C=1.0

svc_classifier1 = svm.SVC(kernel='linear', C=C).fit(X1, y1)
Z1 = svc_classifier.predict(X_plot)
print (Z1.shape)
Z1= Z1.reshape(xx1.shape)
print (Z1.shape)

'''
plt.figure(figsize=(15, 5))
plt.subplot(121)
plt.contourf(xx, yy, Z, cmap=plt.cm.tab10, alpha=0.3)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Set1)
plt.xlabel('Petal length')
plt.ylabel('Petal width')
plt.xlim(xx.min(), xx.max())
plt.title('Support Vector Classifier with linear kernel')
'''
# Out:
# 0.0 7.9
# (1,)
# (1, 1)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in double_scalars
#   """
# "\nplt.figure(figsize=(15, 5))\nplt.subplot(121)\nplt.contourf(xx, yy, Z, cmap=plt.cm.tab10, alpha=0.3)\nplt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Set1)\nplt.xlabel('Petal length')\nplt.ylabel('Petal width')\nplt.xlim(xx.min(), xx.max())\nplt.title('Support Vector Classifier with linear kernel')\n"
