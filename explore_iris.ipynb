# %%
import pandas as pd
import numpy as np
from sklearn import datasets
import matplotlib.pyplot as plt

iris_data = datasets.load_iris()
#iris_data
#first : for rows and 2nd is for columns
#iris_data.data[:,:]
#above is same as iris_data since it will print all data
#Now select only 7 rows
iris_data.data[:7,:]
#Now select only 7 rows and 3 column
iris_data.data[:7,:3]
#Now try with different positions
iris_data.data[2:7,1:3]
# Out:
# array([[3.2, 1.3],
#        [3.1, 1.5],
#        [3.6, 1.4],
#        [3.9, 1.7],
#        [3.4, 1.4]])

# %%
plt.figure(figsize = (10, 7)) 
#extract sepel length
x1 = iris_data.data[:,:0] 
  
plt.hist(x1, bins = 20, color = "green") 
plt.title("Sepal Length in cm") 
plt.xlabel("Sepal_Length_cm") 
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.figure(figsize = (10, 7)) 
#extract sepel width
x2 = iris_data.data[:,1:2] 
  
plt.hist(x2, bins = 20, color = "green") 
plt.title("Sepal Width in cm") 
plt.xlabel("Sepal_Width_cm") 
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.figure(figsize = (10, 7)) 
#extract Petal Length
x3 = iris_data.data[:,2:3] 
  
plt.hist(x3, bins = 20, color = "green") 
plt.title("Petal Length in cm") 
plt.xlabel("Petal_Length_cm") 
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.figure(figsize = (10, 7)) 
#extract Petal Width
x4 = iris_data.data[:,3:4] 
  
plt.hist(x4, bins = 20, color = "green") 
plt.title("Petal Width in cm") 
plt.xlabel("Petal_Width_cm") 
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
X = iris_data.data[:, 0:2]
y = iris_data.target

#print (X,y)

#plt.figure(figsize=(15, 5))
#plt.subplot(121)
#plt.contourf(xx, yy, Z, cmap=plt.cm.tab10, alpha=0.3)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Set1)
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
#plt.xlim(xx.min(), xx.max())
plt.title('Scatter plot between Sepal length and Sepal Width')
# Out:
# Text(0.5, 1.0, 'Scatter plot between Sepal length and Sepal Width')

# %%
X = iris_data.data[:, 2:4]
y = iris_data.target

#print (X,y)

#plt.figure(figsize=(15, 5))
#plt.subplot(121)
#plt.contourf(xx, yy, Z, cmap=plt.cm.tab10, alpha=0.3)
#plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Set1)
plt.scatter(X[:, 0], X[:, 1],c=y)
plt.xlabel('Petal length')
plt.ylabel('Petal width')
#plt.xlim(xx.min(), xx.max())
plt.title('Scatter plot between Petal length and Petal Width')
# Out:
# Text(0.5, 1.0, 'Scatter plot between Petal length and Petal Width')

# %%
df = pd.DataFrame(data=iris_data['data'],columns=iris_data['feature_names'])
df['species'] = pd.Categorical.from_codes(iris_data.target, iris_data.target_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
import seaborn as sns
plt.style.use('seaborn')

sns.pairplot(data=df,kind='scatter', hue='species')
